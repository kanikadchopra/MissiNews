# %% [markdown]
# # Mississauga News Analysis
#
# We will be using Tweets from the Mississauga News to conduct our analysis.
# The focus of this analysis is on the crime in Mississauga to see if there are increases during certain months, and if it is increasing yearly.
#
# By: Kanika Chopra

# %% [markdown]
# ## Importing Libraries
#
# We begin by importing the necessary libraries for the analysis.

# %%
import numpy as np
import pandas as pd

import spacy
from spacy import displacy
import string

import nltk
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

from collections import Counter

import contractions
from string import punctuation

from nlp import *
from similarity import *

# %% [markdown]
# ## Importing Data
# We get our data from downloading it to a csv file and then importing the Mississauga News tweets that we have scraped from the Mississauga News twitter account.

# %%
df = pd.read_csv('MissiNewsRoom_tweets.csv')

# Let's take a look at our data 
df.head()
# Out:
#    Unnamed: 0                   id                 Date  \
# 0           0  1194057385817587714  2019-11-12 01:00:39
# 1           1  1194042230106931206  2019-11-12 00:00:26
# 2           2  1193998304163565571  2019-11-11 21:05:53
# 3           3  1193981803742289921  2019-11-11 20:00:19
# 4           4  1193980972355723264  2019-11-11 19:57:01
#
#                                                Tweet
# 0  A badly broken leg could have ended #Brampton ...
# 1  NEW BUSINESS: Align Custom Fit Footwear &amp; ...
# 2  ‘Right time for him to immediately step down’:...
# 3  Where were you 40 years ago during the #Missis...
# 4  Canadian Broadcast Standards Council says it c...

# %%
# Columns of our excel file
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Date', 'Tweet'], dtype='object')

# %% [markdown]
# ## Data Pre-Processing
# Lets get our data into the form we need for the NLP work we'll be doing

# %%
# Let's drop the unnecessary columns
df.drop(columns=['Unnamed: 0', 'id'], inplace=True)
df.columns = ['Timestamp', 'Tweet']

df.head()
# Out:
#              Timestamp                                              Tweet
# 0  2019-11-12 01:00:39  A badly broken leg could have ended #Brampton ...
# 1  2019-11-12 00:00:26  NEW BUSINESS: Align Custom Fit Footwear &amp; ...
# 2  2019-11-11 21:05:53  ‘Right time for him to immediately step down’:...
# 3  2019-11-11 20:00:19  Where were you 40 years ago during the #Missis...
# 4  2019-11-11 19:57:01  Canadian Broadcast Standards Council says it c...

# %% [markdown]
# ### Dates
# We begin with having the overall timestamp, we want to break it down into Date, Time and then separate months and years in case we want to compare monthly and yearly data.

# %%
# Break the Date apart into Date and Time 
df['Time'] = df['Timestamp'].apply(lambda x: x[10:])
df['Date'] = df['Timestamp'].apply(lambda x: x[:10])
df['Month'] = df['Date'].apply(lambda x: x[5:7])
df['Year'] = df['Date'].apply(lambda x: x[:4])

# Reorder the columns
df = df[['Date', 'Year', 'Month', 'Time', 'Tweet']]

df.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-11-12  2019    11   01:00:39
# 1  2019-11-12  2019    11   00:00:26
# 2  2019-11-11  2019    11   21:05:53
# 3  2019-11-11  2019    11   20:00:19
# 4  2019-11-11  2019    11   19:57:01
#
#                                                Tweet
# 0  A badly broken leg could have ended #Brampton ...
# 1  NEW BUSINESS: Align Custom Fit Footwear &amp; ...
# 2  ‘Right time for him to immediately step down’:...
# 3  Where were you 40 years ago during the #Missis...
# 4  Canadian Broadcast Standards Council says it c...

# %% [markdown]
# ### Links
# We have the links to the actual Mississauga News article included in the tweet. We are going to separate this from the bulk of the tweet; this way if we want to look at these articles for more information, we have access to the tweets.

# %%
# We need to separate the link from the tweet
df['Link'] = df['Tweet'].apply(lambda x: 'http' + x.split('http')[1] if 'http' in x else '')
df['Tweet'] = df['Tweet'].apply(lambda x: x.split('http')[0] if 'http' in x else x)

# Break apart all contractions (except name possession e.g. Sarah's)
df['Tweet'] = df['Tweet'].apply(lambda x: contractions.fix(x))

# %%
# Let's create another DataFrame with the original tweets in case we need to view them
original = df.copy()

original.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-11-12  2019    11   01:00:39
# 1  2019-11-12  2019    11   00:00:26
# 2  2019-11-11  2019    11   21:05:53
# 3  2019-11-11  2019    11   20:00:19
# 4  2019-11-11  2019    11   19:57:01
#
#                                                Tweet                      Link
# 0  A badly broken leg could have ended #Brampton ...  https://t.co/mgndlYyBhz
# 1  NEW BUSINESS: Align Custom Fit Footwear &amp; ...  https://t.co/hFvGVGsF8n
# 2  ‘Right time for him to immediately step down’:...   https://t.co/x4oxb4LaDD
# 3  Where were you 40 years ago during the #Missis...   https://t.co/UmHGqFToqh
# 4  Canadian Broadcast Standards Council says it c...   https://t.co/6l2RIg8EpP

# %% [markdown]
# ### Tokenization and Lemmatization
# We are going to tokenize all the words, lemmatize them and store them in a list for the bag of words approach.
#
# We're going to compare nltk and spaCy to see which works better for this use case. For nltk, we tokenize the words using a RegexpTokenizer to exclude punctuation, and then lemmatize it. spaCy will parse the sentences for each tweet and then lemmatize each token.
#
# #### nltk Lemmatization
#
# To use nltk wordnet, we need to import a created function that gets the POS tag so that we can use nltk's Wordnet Lemmatizer with the appropriate POS tag. This gets passed in as the second argument to lemmatize() once it is initialized.

# %%
# Initialize the tokenizer so that it doesn't include punctuation 
tokenizer = RegexpTokenizer(r'\w+')

# %%
# Change everything to lowercase words
df['Tweet'] = df['Tweet'].apply(lambda x: x.lower())

# Tokenization 
df['nltk_Tweet'] = [tokenizer.tokenize(x) for x in df['Tweet']]

# %%
# Remove stop words
stop_words = set(stopwords.words('english'))

df['nltk_Tweet'] = df['nltk_Tweet'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\RQ\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\RQ\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Convert words to root word (e.g. 'shooting to shoot')
df['nltk_Tweet'] = df['nltk_Tweet'].apply(lambda x: [lemmatizer.lemmatize(word, get_pos(word)) for word in x])

# Let's take a look at our data now 
df.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-11-12  2019    11   01:00:39
# 1  2019-11-12  2019    11   00:00:26
# 2  2019-11-11  2019    11   21:05:53
# 3  2019-11-11  2019    11   20:00:19
# 4  2019-11-11  2019    11   19:57:01
#
#                                                Tweet  \
# 0  a badly broken leg could have ended #brampton ...
# 1  new business: align custom fit footwear &amp; ...
# 2  ‘right time for him to immediately step down’:...
# 3  where were you 40 years ago during the #missis...
# 4  canadian broadcast standards council says it c...
#
#                        Link                                         nltk_Tweet
# 0  https://t.co/mgndlYyBhz   [badly, broken, leg, could, end, brampton, nat...
# 1  https://t.co/hFvGVGsF8n   [new, business, align, custom, fit, footwear, ...
# 2   https://t.co/x4oxb4LaDD  [right, time, immediately, step, sportsnet, cu...
# 3   https://t.co/UmHGqFToqh  [40, year, ago, mississauga, miracle, train, d...
# 4   https://t.co/6l2RIg8EpP  [canadian, broadcast, standard, council, say, ...

# %% [markdown]
# #### spaCy Lemmatization

# %%
df2 = original.copy()

# Initialize spacy 'en_core_web_sm' model, keeping only tagger component needed for lemmatization
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Lemmatize the tweet
df2['spacy_Tweet'] = df2['Tweet'].apply(lambda x: spacy_lemmatize(x))

# Remove punctuation from spacy_Tweets
df2['spacy_Tweet'] = df2['spacy_Tweet'].apply(lambda x: [word for word in x if word.isalpha()])

# Let's view our data now 
df2.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-11-12  2019    11   01:00:39
# 1  2019-11-12  2019    11   00:00:26
# 2  2019-11-11  2019    11   21:05:53
# 3  2019-11-11  2019    11   20:00:19
# 4  2019-11-11  2019    11   19:57:01
#
#                                                Tweet  \
# 0  A badly broken leg could have ended #Brampton ...
# 1  NEW BUSINESS: Align Custom Fit Footwear &amp; ...
# 2  ‘Right time for him to immediately step down’:...
# 3  Where were you 40 years ago during the #Missis...
# 4  Canadian Broadcast Standards Council says it c...
#
#                        Link                                        spacy_Tweet
# 0  https://t.co/mgndlYyBhz   [a, badly, broken, leg, could, have, end, bram...
# 1  https://t.co/hFvGVGsF8n   [new, business, align, custom, fit, footwear, ...
# 2   https://t.co/x4oxb4LaDD  [right, time, for, to, immediately, step, spor...
# 3   https://t.co/UmHGqFToqh  [where, be, year, ago, during, the, mississaug...
# 4   https://t.co/6l2RIg8EpP  [canadian, broadcast, standards, council, say,...

# %% [markdown]
# ### nltk vs. spaCy
# We'll compare the first and last tweet tokenization and lemmatization using both libraries.

# %%
# nltk Tweet
' '.join(df['nltk_Tweet'][0])
# Out:
# 'badly broken leg could end brampton native tyler ennis career surgery countless rehab hour play raptors905 mississauga'

# %%
# spaCy Tweet
' '.join(df2['spacy_Tweet'][0])
# Out:
# 'a badly broken leg could have end brampton native tyler career but after surgery and countless rehab hour be play again with in mississauga'

# %% [markdown]
# As we can see, the spaCy approach keeps words such as 'a', 'but', 'with' which are words that are not useful for our bag of words approach if we are trying to get the common topics in the news. Thus, we will use the nltk approach to tokenize and lemmatize our tweets and continue with this.

# %% [markdown]
# ## Bag of Words Approach
# We take the list of tokens in each of the tweets, and based on the month, we're going to take the 10 most common tokens and their frequency.

# %%
# Let's combine the sentences back together for later use
df['cleaned_Tweet'] = df['nltk_Tweet'].apply(lambda x: ' '.join(x))

df.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-11-12  2019    11   01:00:39
# 1  2019-11-12  2019    11   00:00:26
# 2  2019-11-11  2019    11   21:05:53
# 3  2019-11-11  2019    11   20:00:19
# 4  2019-11-11  2019    11   19:57:01
#
#                                                Tweet  \
# 0  a badly broken leg could have ended #brampton ...
# 1  new business: align custom fit footwear &amp; ...
# 2  ‘right time for him to immediately step down’:...
# 3  where were you 40 years ago during the #missis...
# 4  canadian broadcast standards council says it c...
#
#                        Link  \
# 0  https://t.co/mgndlYyBhz
# 1  https://t.co/hFvGVGsF8n
# 2   https://t.co/x4oxb4LaDD
# 3   https://t.co/UmHGqFToqh
# 4   https://t.co/6l2RIg8EpP
#
#                                           nltk_Tweet  \
# 0  [badly, broken, leg, could, end, brampton, nat...
# 1  [new, business, align, custom, fit, footwear, ...
# 2  [right, time, immediately, step, sportsnet, cu...
# 3  [40, year, ago, mississauga, miracle, train, d...
# 4  [canadian, broadcast, standard, council, say, ...
#
#                                        cleaned_Tweet
# 0  badly broken leg could end brampton native tyl...
# 1  new business align custom fit footwear amp foo...
# 2  right time immediately step sportsnet cut tie ...
# 3   40 year ago mississauga miracle train derailment
# 4  canadian broadcast standard council say take c...

# %%
# Let's try to do this with the first month (Month = 1)
Jan = df[df['Month'] == '01']
Jan.reset_index(inplace=True,drop=True)

Jan.head()
# Out:
#          Date  Year Month       Time  \
# 0  2019-01-31  2019    01   22:05:25
# 1  2019-01-31  2019    01   20:55:37
# 2  2019-01-31  2019    01   14:44:31
# 3  2019-01-31  2019    01   14:06:06
# 4  2019-01-31  2019    01   12:28:11
#
#                                                Tweet  \
# 0  it is #throwbackthursday time! is not this the...
# 1  rt @bramptonfirees: @bramptontransit @1010traf...
# 2  update: another multi-vehicle crash in #missis...
# 3  have you seen her? aliaiyda temiz was last see...
# 4  warning: police are cautioning drivers about i...
#
#                        Link  \
# 0  https://t.co/kmtxpQOWv9
# 1
# 2  https://t.co/bwT1FFKe77
# 3  https://t.co/6xoldbdNnm
# 4  https://t.co/f5pVuXo69t
#
#                                           nltk_Tweet  \
# 0          [throwbackthursday, time, year, pig, tbt]
# 1  [rt, bramptonfirees, bramptontransit, 1010traf...
# 2  [update, another, multi, vehicle, crash, missi...
# 3  [see, aliaiyda, temiz, last, see, late, yester...
# 4  [warn, police, caution, driver, icy, road, con...
#
#                                        cleaned_Tweet
# 0                throwbackthursday time year pig tbt
# 1  rt bramptonfirees bramptontransit 1010traffic ...
# 2  update another multi vehicle crash mississauga...
# 3  see aliaiyda temiz last see late yesterday aft...
# 4  warn police caution driver icy road condition ...

# %% [markdown]
# We need to take every tweet's list of words and combine them into one list to be used in the bag of words.

# %%
all_words = [] 
for i in range(len(Jan)):
    lst = Jan.loc[i]['nltk_Tweet']
    all_words.extend(lst)
    
# How many words do we have?
len(all_words)
# Out:
# 2693

# %%
# Bag of Words with all the tweets for the first month
bagofwords = Counter(all_words)

bagofwords.most_common(10)
# Out:
# [('mississauga', 132),
#  ('police', 35),
#  ('peel', 33),
#  ('year', 31),
#  ('news', 28),
#  ('man', 25),
#  ('break', 23),
#  ('brampton', 18),
#  ('new', 18),
#  ('rt', 16)]

# %% [markdown]
# We can see that police is the second most common topic mentioned. So let's take a look at some of the tweets associated with the police

# %%
# Let's take the first month of original tweets 
Jan_original = original[original['Month'] == '01']
Jan_original.reset_index(inplace=True, drop=True)

Jan_police = Jan_original[Jan_original['Tweet'].str.contains('police')]['Tweet']
Jan_police.reset_index(inplace=True, drop=True)

police_tweets = []
for tweet in Jan_police:
    police_tweets.append(tweet)
    
police_tweets
# Out:
# ['His company was supposed to help people scammed by door-to-door sales. But police have now charged him with fraud. #Brampton #Mississauga ',
#  'BREAKING NEWS: Massive #snowstorm hits #Mississauga with classes and other events being cancelled as the #snow continues to pile up, prompting a warning from police about #driving conditions: ',
#  '‘This guy has a death wish’: This #Audi was caught going at a crazy #speed on #hwy403 in #Mississauga near Square One, prompting a stern police warning to drivers: ',
#  '#Peel police are reminding residents what is allowed and what is not when it comes to recreational #cannabis after #Mississauga’s neighbour #Brampton gives green light to retail stores\n',
#  'BREAKING NEWS: Police ID and name suspect in vicious sexual assault inside Square One mall @shopSQUAREONE in #Mississauga that left a young woman traumatized. A #warrant is out for his arrest and he is known to police: ',
#  'BREAKING NEWS: Heavy police and paramedic presence after #bomb threat made at Credit Valley Hospital in #Mississauga this evening. @Trillium_Health : ',
#  'THIS JUST IN: Young woman #sexually assaulted inside Square One in #Mississauga and police allege this man is responsible for the #attack. he is still on the run: ',
#  'BREAKING NEWS: A #Mississauga man serving time for #guns and drug trafficking #crimes has disappeared and police need help finding him: ',
#  'A Toronto woman was arrested and is facing a rash of charges after evading police in a stolen vehicle and striking an officer and a truck yesterday afternoon in Mississauga. \n',
#  'PHOTOS ADDED: #Peel police officer and suspect taken to hospital with injuries. Shots were fired by police during the incident in #Mississauga but no one was hit.\n',
#  "BREAKING NEWS – 'Officer has been injured’: #Peel police investigating stolen vehicle near Tomken and Eglinton in #Mississauga\n",
#  'THIS JUST IN: #Peel police say they have identified a suspect in #Mississauga hit-and-run that sent a senior citizen to hospital with serious injuries.\n']

# %% [markdown]
# ## Police and Crime Analysis
# We are going to take the tweets that are related to police, assault, shootings, stabbings and robberies to compare those crimes first.

# %%
# Set the crime_words that we are focusing on first
crime_words = ['police', 'shoot',  'stab', 'robs', 'robbery', 'assault']

# %%
Jan_crime = pd.DataFrame(columns=Jan.columns)

for word in crime_words:
    subset = Jan[Jan['cleaned_Tweet'].str.contains(word)]
    subset['word'] = word
    Jan_crime = Jan_crime.append(subset)
    
Jan_crime.reset_index(inplace=True,drop=True)
len(Jan_crime)
# Out:
# C:\Users\RQ\Anaconda3\envs\project\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\RQ\Anaconda3\envs\project\lib\site-packages\pandas\core\frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# 50

# %%
Jan_crime
# Out:
#           Date                      Link Month       Time  \
# 0   2019-01-31  https://t.co/bwT1FFKe77     01   14:44:31
# 1   2019-01-31  https://t.co/f5pVuXo69t     01   12:28:11
# 2   2019-01-30  https://t.co/Gg8d60xV51     01   18:36:50
# 3   2019-01-30  https://t.co/zboaK5xpSS     01   11:54:41
# 4   2019-01-29  https://t.co/3lB7CGKLQb     01   14:57:43
# 5   2019-01-28   https://t.co/iV9UPOgc6c    01   18:37:16
# 6   2019-01-25   https://t.co/nTiv9MC75V    01   19:43:00
# 7   2019-01-25   https://t.co/txQ7wLWYvN    01   16:05:58
# 8   2019-01-25   https://t.co/1j3XFkekcy    01   13:02:47
# 9   2019-01-25   https://t.co/by08kU6yzf    01   01:30:25
# 10  2019-01-22   https://t.co/gmbNh8pJ0g    01   19:50:28
# 11  2019-01-21   https://t.co/zLozYVXhV6    01   19:08:15
# 12  2019-01-18   https://t.co/b79tvu10Yw    01   16:46:06
# 13  2019-01-16   https://t.co/XhimQ8xUeW    01   20:58:26
# 14  2019-01-16   https://t.co/y0RAdQ3Dlr    01   01:37:05
# 15  2019-01-16   https://t.co/dkTF2oR4Om    01   01:13:48
# 16  2019-01-15   https://t.co/D9amu4gWxp    01   14:24:20
# 17  2019-01-14   https://t.co/vL7RsvjIYs    01   17:16:33
# 18  2019-01-13  https://t.co/Y33sUXOAzJ     01   22:12:09
# 19  2019-01-13  https://t.co/JFTrsKXDNY     01   19:32:25
# 20  2019-01-12  https://t.co/5mmQFVj4AI     01   19:46:19
# 21  2019-01-12  https://t.co/fuGqu44gja     01   15:21:36
# 22  2019-01-11  https://t.co/qlyLCJ5KdB     01   19:22:12
# 23  2019-01-11  https://t.co/67TFQCNQF2     01   18:54:18
# 24  2019-01-11   https://t.co/ocraJWUlKE    01   16:41:00
# 25  2019-01-11  https://t.co/Nqb6sKsq98     01   14:00:00
# 26  2019-01-09  https://t.co/010lS7ucxy     01   14:28:34
# 27  2019-01-08  https://t.co/fU8kLAE3Ae     01   19:05:31
# 28  2019-01-07   https://t.co/mxVlCVWIwa    01   18:42:43
# 29  2019-01-07   https://t.co/Xy3MU97enp    01   14:58:12
# 30  2019-01-05  https://t.co/mxVlCWejnI     01   15:00:02
# 31  2019-01-04   https://t.co/padfzIHUUd    01   17:48:15
# 32  2019-01-03  https://t.co/hGsrg2U4OS     01   20:44:47
# 33  2019-01-02  https://t.co/75mwwt1xbu     01   14:17:53
# 34  2019-01-23   https://t.co/45pdUfpmLf    01   11:03:36
# 35  2019-01-11   https://t.co/ocraJWUlKE    01   16:41:00
# 36  2019-01-04   https://t.co/VkxPA1Mu7t    01   04:04:17
# 37  2019-01-25   https://t.co/koDoUlnI0Q    01   11:44:43
# 38  2019-01-22  https://t.co/h01QJPoh11     01   13:00:01
# 39  2019-01-11   https://t.co/ocraJWUlKE    01   16:41:00
# 40  2019-01-09  https://t.co/010lS7ucxy     01   14:28:34
# 41  2019-01-07   https://t.co/XBP0DQuTcZ    01   22:43:56
# 42  2019-01-04   https://t.co/cfsliI5XOc    01   03:29:16
# 43  2019-01-25   https://t.co/hpt0oj0TjP    01   17:32:58
# 44  2019-01-23   https://t.co/gokCRVJCMW    01   20:04:23
# 45  2019-01-17   https://t.co/zQs4HtuDnt    01   04:19:31
# 46  2019-01-16   https://t.co/XhimQ8xUeW    01   20:58:26
# 47  2019-01-16   https://t.co/dkTF2oR4Om    01   01:13:48
# 48  2019-01-12  https://t.co/5mmQFVj4AI     01   19:46:19
# 49  2019-01-10   https://t.co/8gqtbnVBcd    01   18:49:00
#
#                                                 Tweet  Year  \
# 0   update: another multi-vehicle crash in #missis...  2019
# 1   warning: police are cautioning drivers about i...  2019
# 2   rise in mental health calls to @peelpolicemedi...  2019
# 3   have you seen this man? peel regional police a...  2019
# 4   his company was supposed to help people scamme...  2019
# 5   breaking news: massive #snowstorm hits #missis...  2019
# 6   warning: police hunting 2 distraction thieves ...  2019
# 7   ‘this guy has a death wish’: this #audi was ca...  2019
# 8   just in: police identify and name #mississauga...  2019
# 9   this just in: police looking for surveillance ...  2019
# 10  #peel police are reminding residents what is a...  2019
# 11  breaking news: police raid and shut down illeg...  2019
# 12  breaking news: the peel regional police servic...  2019
# 13  breaking news: police id and name suspect in v...  2019
# 14  breaking news: heavy police and paramedic pres...  2019
# 15  this just in: young woman #sexually assaulted ...  2019
# 16  caught on video: #suv hits man on motorized #w...  2019
# 17  breaking news: a #mississauga man serving time...  2019
# 18  buyer beware: peel police say there have recei...  2019
# 19  police have arrested a 23-year-old man in conn...  2019
# 20  police have arrested a 44-year-old man after f...  2019
# 21  a toronto woman was arrested and is facing a r...  2019
# 22  photos added: #peel police officer and suspect...  2019
# 23  breaking news – 'officer has been injured’: #p...  2019
# 24  this just in: police #shooting and #crash near...  2019
# 25  #peel regional police chief jennifer evans' la...  2019
# 26  police are searching for two men involved in t...  2019
# 27  this just in: #peel police say they have ident...  2019
# 28  ‘our frontline officers are tired, burned out ...  2019
# 29  breaking news: strong smell of natural #gas br...  2019
# 30  some background on the upcoming peel regional ...  2019
# 31  ‘there may be more victims’: 2 young men and a...  2019
# 32  have you seen her? police are searching for 91...  2019
# 33  have you seen him?: police are searching for d...  2019
# 34  this just in: gunman on the run after #shootin...  2019
# 35  this just in: police #shooting and #crash near...  2019
# 36  breaking news: gunman hunted after #shooting o...  2019
# 37  ‘there were screams’: #stabbing at #mississaug...  2019
# 38  because for concern: 12 establishments, includ...  2019
# 39  this just in: police #shooting and #crash near...  2019
# 40  police are searching for two men involved in t...  2019
# 41  ‘shaken up’: #gun pulled out during #robbery a...  2019
# 42  breaking news: customers left stunned and fear...  2019
# 43  just in: federal offender serving time for #gu...  2019
# 44  opinion | women four times more likely to expe...  2019
# 45  breaking news: arrest made tonight in violent ...  2019
# 46  breaking news: police id and name suspect in v...  2019
# 47  this just in: young woman #sexually assaulted ...  2019
# 48  police have arrested a 44-year-old man after f...  2019
# 49  broken clavicle and cheekbone, 9 #broken ribs,...  2019
#
#                                         cleaned_Tweet  \
# 0   update another multi vehicle crash mississauga...
# 1   warn police caution driver icy road condition ...
# 2   rise mental health call peelpolicemedia sympto...
# 3   see man peel regional police search matthew ho...
# 4   company suppose help people scammed door door ...
# 5   break news massive snowstorm hit mississauga c...
# 6   warn police hunt 2 distraction thief target mi...
# 7   guy death wish audi caught go crazy speed hwy4...
# 8   police identify name mississauga man accuse dr...
# 9   police look surveillance footage pedestrian hi...
# 10  peel police remind resident allow come recreat...
# 11  break news police raid shut illegal marijuana ...
# 12  break news peel regional police service board ...
# 13  break news police id name suspect vicious sexu...
# 14  break news heavy police paramedic presence bom...
# 15  young woman sexually assault inside square one...
# 16  caught video suv hit man motorize wheelchair m...
# 17  break news mississauga man serve time gun drug...
# 18  buyer beware peel police say receive several r...
# 19  police arrest 23 year old man connection two r...
# 20  police arrest 44 year old man find incident se...
# 21  toronto woman arrest face rash charge evade po...
# 22  photo add peel police officer suspect take hos...
# 23  break news officer injured peel police investi...
# 24  police shoot crash near square one mississauga...
# 25  peel regional police chief jennifer evans last...
# 26  police search two men involve robbery restaura...
# 27  peel police say identify suspect mississauga h...
# 28  frontline officer tire burn always ask less pe...
# 29  break news strong smell natural gas brings hea...
# 30  background upcoming peel regional police budge...
# 31  may victim 2 young men young woman charge dist...
# 32  see police search 91 year old wladyslawa gorle...
# 33  see police search danijel dugonjic mississauga...
# 34  gunman run shoot mississauga neighbourhood lea...
# 35  police shoot crash near square one mississauga...
# 36  break news gunman hunt shoot outside mississau...
# 37  scream stab mississauga home leaf mother life ...
# 38  concern 12 establishment include two second cu...
# 39  police shoot crash near square one mississauga...
# 40  police search two men involve robbery restaura...
# 41  shaken gun pull robbery mcdonaldscanada missis...
# 42  break news customer left stun fearful robbery ...
# 43  federal offender serve time gun assault crime ...
# 44  opinion woman four time likely experience sexu...
# 45  break news arrest make tonight violent sex ass...
# 46  break news police id name suspect vicious sexu...
# 47  young woman sexually assault inside square one...
# 48  police arrest 44 year old man find incident se...
# 49  broken clavicle cheekbone 9 broken rib swell b...
#
#                                            nltk_Tweet     word
# 0   [update, another, multi, vehicle, crash, missi...   police
# 1   [warn, police, caution, driver, icy, road, con...   police
# 2   [rise, mental, health, call, peelpolicemedia, ...   police
# 3   [see, man, peel, regional, police, search, mat...   police
# 4   [company, suppose, help, people, scammed, door...   police
# 5   [break, news, massive, snowstorm, hit, mississ...   police
# 6   [warn, police, hunt, 2, distraction, thief, ta...   police
# 7   [guy, death, wish, audi, caught, go, crazy, sp...   police
# 8   [police, identify, name, mississauga, man, acc...   police
# 9   [police, look, surveillance, footage, pedestri...   police
# 10  [peel, police, remind, resident, allow, come, ...   police
# 11  [break, news, police, raid, shut, illegal, mar...   police
# 12  [break, news, peel, regional, police, service,...   police
# 13  [break, news, police, id, name, suspect, vicio...   police
# 14  [break, news, heavy, police, paramedic, presen...   police
# 15  [young, woman, sexually, assault, inside, squa...   police
# 16  [caught, video, suv, hit, man, motorize, wheel...   police
# 17  [break, news, mississauga, man, serve, time, g...   police
# 18  [buyer, beware, peel, police, say, receive, se...   police
# 19  [police, arrest, 23, year, old, man, connectio...   police
# 20  [police, arrest, 44, year, old, man, find, inc...   police
# 21  [toronto, woman, arrest, face, rash, charge, e...   police
# 22  [photo, add, peel, police, officer, suspect, t...   police
# 23  [break, news, officer, injured, peel, police, ...   police
# 24  [police, shoot, crash, near, square, one, miss...   police
# 25  [peel, regional, police, chief, jennifer, evan...   police
# 26  [police, search, two, men, involve, robbery, r...   police
# 27  [peel, police, say, identify, suspect, mississ...   police
# 28  [frontline, officer, tire, burn, always, ask, ...   police
# 29  [break, news, strong, smell, natural, gas, bri...   police
# 30  [background, upcoming, peel, regional, police,...   police
# 31  [may, victim, 2, young, men, young, woman, cha...   police
# 32  [see, police, search, 91, year, old, wladyslaw...   police
# 33  [see, police, search, danijel, dugonjic, missi...   police
# 34  [gunman, run, shoot, mississauga, neighbourhoo...    shoot
# 35  [police, shoot, crash, near, square, one, miss...    shoot
# 36  [break, news, gunman, hunt, shoot, outside, mi...    shoot
# 37  [scream, stab, mississauga, home, leaf, mother...     stab
# 38  [concern, 12, establishment, include, two, sec...     stab
# 39  [police, shoot, crash, near, square, one, miss...  robbery
# 40  [police, search, two, men, involve, robbery, r...  robbery
# 41  [shaken, gun, pull, robbery, mcdonaldscanada, ...  robbery
# 42  [break, news, customer, left, stun, fearful, r...  robbery
# 43  [federal, offender, serve, time, gun, assault,...  assault
# 44  [opinion, woman, four, time, likely, experienc...  assault
# 45  [break, news, arrest, make, tonight, violent, ...  assault
# 46  [break, news, police, id, name, suspect, vicio...  assault
# 47  [young, woman, sexually, assault, inside, squa...  assault
# 48  [police, arrest, 44, year, old, man, find, inc...  assault
# 49  [broken, clavicle, cheekbone, 9, broken, rib, ...  assault

# %% [markdown]
# We have 50 tweets in January relating to crime, we've added a section to show which word was associated with the tweet.

# %%
# Let's take a look at our data
Jan_crime['word'].value_counts()
# Out:
# police     34
# assault     7
# robbery     4
# shoot       3
# stab        2
# Name: word, dtype: int64

# %%
# Let's see what our time period was (our minimum and maximum date)
min_date, max_date = min(Jan_crime['Date']), max(Jan_crime['Date'])

min_date, max_date
# Out:
# ('2019-01-02', '2019-01-31')

# %% [markdown]
# So we can see that from January 4th, 2019 until January 29th, 2019, there are were 34 police incidents, 7 assaults, 4 robberies, 3 shootings, and 2 stabbings. Let's take a deeper look at this!

# %% [markdown]
# ## Tweet Similarity
#
# One issue our dataset could have is tweets based on the same newspiece; having similar articles could cause inaccuracy issues in our data. We are going to check the text similarity with the Tweets using Jacard Similarity and Cosine Similarity and comparing the two methods.

# %%
word_vectors = spacy.load('en_vectors_web_lg')

# %%
# Take a series of the cleaned tweets in January crime
ser = Jan_crime['cleaned_Tweet']

# Convert it to an array 
crimes = ser.values

# %%
# Create an empty similarity matrix
similarity_matrix = np.zeros([len(crimes), len(crimes)])

similarity_matrix

# %%
# Implement a similarity matrix
for i, sentence_i in enumerate(crimes):
    for j, sentence_j in enumerate(crimes):
        if i!=j:
            similarity_matrix[i][j] = cosine(sentence_i, sentence_j)

# %%
crimes.values

# %%
sentence_i = crimes[0]
sentence_j = crimes[1]

# %%
cosine(sentence_i, sentence_j)
